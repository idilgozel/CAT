# %% [markdown]
# # Task 2 — Collaborative Software Projects
#
# This task concerns the practices and infrastructure of collaborative software development on GitHub. All questions refer to the `allocations` repository in this directory.
#
# **Total marks: 25**
#
# ---

# %% [markdown]
# ## Part A (7)
#
# - (2) Explain the distinction between *Git* and *GitHub*. Provide one feature offered by GitHub that is **not** part of Git itself, and one capability of Git that exists independently of GitHub. No need to answer this not a good question
#
# - (2) The `allocations` repository contains a `README.md` file at its top level. State two distinct categories of information that should appear in this file, with a one-line justification for each.
# - (2) The repository currently contains no `LICENSE` or `CITATION` file. Explain, in one sentence each, what each of these files is for and why a research software project should provide them.
# - (1) Looking at the file/folder structure of this repository (`src/`, `tests/`, `docs/`, `examples/`, `pyproject.toml`, `.github/`, `.gitignore`), state which of these directories or files would typically contain *continuous integration* configuration.

# %% [markdown]
# ### Answer — Part A
# README.md should contain project description (what project does and purpose) and installation, usage inormation
#
# The licence lets people know whether they can reuse your code and under what terms.Citation is important to avoid plagiarism in open source  code, it is also a good way for people to be aware of the codeand where to find it.
#
# pyproject.toml would contain CI configuration.

# %% [markdown]
# ## Part B (8)
#
# Daedalus does not have write access to the `allocations` repository, but he has spotted a bug in `allocations.solvers.greedy` and wants to contribute a fix.
#
# - (2) Describe what a *fork* of a repository is, and explain why external collaborators are typically expected to use forks rather than direct clones-with-write-access to contribute to a project.
# - (3) In order, list the steps Daedalus should take to land his fix into the upstream `allocations` repository, starting from clicking *Fork* on GitHub and ending with his fix being merged into `main`. You should mention: branches, pushing to his fork, pull requests, code review, and what should happen if a maintainer requests changes.
# - (1) Explain why pull request review is considered an important part of the development life cycle, even when automated tests already pass.
# - (2) Daedalus's pull request adds a new test in `tests/test_allocations.py`, but the maintainer also asks him to update `README.md`. Explain why a maintainer might insist on documentation changes in the *same* PR rather than a follow-up PR. Give one situation in which the **opposite** convention (split into separate PRs) would be more appropriate.

# %% [markdown]
# ### Answer — Part B
#
# By forking a repository, all you do is make a copy of it in your GitHub account, where you will have write permissions as well. Once you are happy with with the changes, GitHub also offers you a way to notify Numpy's developers of this changes so that they can include them in the official repository via starting a Pull Request.
#
# 1. fork
# 2. clone his fork
# 3. create branch
# 4. make changes on branch
# 5. run tests
# 6. stage and commit changes on branch
# 6. push changes to his fork
# 7. open pull request (explain changes here)
# 8. CI reviews code
# if maintainer requests changes make those changes on the same branch test commit and push again and wait for CI review. Once CI passes and maintainer approves merge into main branch.
#
# CI will only test whether the code works not whether it is understandable well explained and well written. PR review can adresss those issues and contribute to code quality .
#
#
#
#
# If maintainer didnt; insist on this and the code got merged then the merged code would have the correct code but wrong information on README.md (even if temporarily). README should be simultaneously updated so that user can know the correct beaviour. When code fixes are unrelated  ,like code changes in independent files, seperate PR are bette. These woulde easier to review.

# %% [markdown]
# ## Part C (10)
#
# - (3) The `allocations` team is debating whether to adopt a more *Agile* development style, in which features are released in many small increments, or a *Waterfall* style, in which the next major release is planned, designed, implemented, tested, and shipped as one. Briefly contrast the two strategies, and recommend which is more appropriate for the `allocations` package given that it is a small research-software project with a handful of users. Justify your recommendation in 2–3 sentences.
#
# - (3) Suppose Daedalus wants to ensure that **every** pull request to the `allocations` repository runs the full pytest suite before it can be merged. Describe the additional pieces of infrastructure he would need to set up. (You do not need to write any YAML — just describe the components and where each one would live in the repository.)
#
# - (4) Below is a (truncated) excerpt of a hypothetical `CONTRIBUTING.md` file someone has drafted for `allocations`:
#
#     > 1. Open an issue describing the bug or feature.
#     > 2. Push your fix directly to `main` so we can release it quickly.
#     > 3. If anyone complains, revert with `git push --force`.
#     > 4. Tests are nice to have but not required.
#
#     Identify **at least three** problems with this contribution policy, and for each one explain what the recommended practice should be and why.

# %% [markdown]
# ### Answer — Part C
# Agile:
# Individuals and interactions over processes and tools
# Working software over comprehensive documentation
# Customer collaboration over contract negotiation
# Responding to change over following a plan
#
# Waterfall:
# first requirements capture, then functional design, then architectural design. This approach is based on the idea that if a mistake is made in the design, then programming effort is wasted, so significant effort is spent in trying to ensure that requirements are well understood and that the design is correct before programming starts.
#
# Agile is better for this case of small group with a handful users where where the small group of programmers are able to communicate  together into well-formulated best practices, and  programmers, designers, clients can work as a team. This may not be possible for very large projects.
#
#
# Push your fix directly to `main` is not a good idea pushing to their own fork and the merging with main after it goes through PR review is a much better idea for so that only good quality code merges with the projet after being approved and bad code can be rejected.
# `git push --force` might overwrite history that might result in other developer work bein lost (deletes other commits), it is generally a bad idea.  Tests should be required otherwise buggy code,or code that directly does not work can be merged with the main project, this is extra disastorous for this workflow since there is also no pull request review

# %% [markdown]
# for mall
