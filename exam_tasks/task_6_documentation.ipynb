# %% [markdown]
# # Task 6 — Documentation
#
# This task concerns user and developer documentation, docstrings, in-line comments, and the use of generators like Sphinx. All questions refer to the `allocations` package, which has its README at `README.md` and additional documentation under `docs/README.md`.
#
# **Total marks: 25**
#
# ---

# %% [markdown]
# ## Part A (6)
#
# - (2) Explain why all software projects, including small research-software projects like `allocations`, should provide some form of documentation. State **two** distinct categories of reader the documentation must serve, and what each one needs.
#
# - (2) Inspect `allocations.io.write_catal` and `Worker.from_mapping` in `allocations.models`. State what a Python *docstring* is and what it can be used for at runtime. Give two pieces of information that a good docstring for `Worker.from_mapping` should convey beyond what the function name already implies.
#
# - (2) Explain the difference between *in-line comments*, *docstrings*, and *expressive code* (i.e. self-describing identifiers and structure) as documentation strategies. Identify which of the three is the best default, and one situation in which each of the others is more appropriate.

# %% [markdown]
# ### Answer — Part A
#
# *Your answer here.*

# %% [markdown]
# ## Part B (7)
#
# - (3) Daedalus has been told that the team will use *Sphinx* to build HTML documentation for `allocations`, and that the build output should not be tracked in git. Explain:
#     1. What kinds of files Sphinx takes as input and what it produces as output.
#     2. Why the generated output is typically excluded from the repository.
#     3. One way the documentation build might be integrated with continuous integration to keep the docs up to date.
#
# - (2) Looking at `README.md` in this repository, identify **two** specific changes you would make so that a brand-new user could successfully install and run the package on their own machine without consulting source code.
#
# - (2) Compare `README.md` in the repo root and `docs/README.md`. Briefly describe what each is for and why having both is reasonable. (You don't need to read the entirety of `docs/README.md`.)

# %% [markdown]
# ### Answer — Part B
#
# *Your answer here.*

# %%
# Optional: inspect README files
from pathlib import Path
# print(Path('../README.md').read_text())
# print(Path('../docs/README.md').read_text()[:2000])

# %% [markdown]
# ## Part C (12)
#
# Daedalus has just written a new helper function in `allocations.matrix` but has not yet documented it:
#
# ```python
# def slot_penalty_breakdown(matrix, assignment):
#     breakdown = []
#     for slot, worker in enumerate(assignment):
#         breakdown.append({"slot": slot, "worker": worker, "penalty": matrix[worker][slot]})
#     return breakdown
# ```
#
# - (4) Write a *docstring* for `slot_penalty_breakdown` whose style is consistent with the rest of `allocations` (look at e.g. `allocations.matrix.expanded_jobs` or `allocations.solvers.solve` for examples). The docstring should clearly describe inputs, outputs, and any edge cases (e.g. an empty `assignment`).
#
# - (4) Add **at most two** in-line comments to the body of `slot_penalty_breakdown` that, in your judgement, are warranted. If you decide *no* in-line comment is warranted, justify that decision in 2–3 sentences. Either way, your answer should reflect the principle that comments should explain *why*, not *what*.
#
# - (4) Daedalus also wants to add a short *user-facing example* in the README showing how a user would use `slot_penalty_breakdown`. In a markdown cell, write a short README section (3–6 lines of prose plus a Python code example) that:
#     1. introduces the helper in plain language,
#     2. shows it in use against the `cat.wkab` example,
#     3. shows the kind of value it returns.

# %%
def slot_penalty_breakdown(matrix, assignment):
    """Your docstring here."""
    breakdown = []
    for slot, worker in enumerate(assignment):
        breakdown.append({"slot": slot, "worker": worker, "penalty": matrix[worker][slot]})
    return breakdown

# %% [markdown]
# ### Answer — README example (C.3)
#
# *Your README section here, in markdown with a fenced code block for the Python example.*
